# %% [markdown]
# <p style="color:#FFF; background:#07D; padding:12px; font-size:20px; font-style:italic; text-align:center">
# <span style="width:49%; display:inline-block; text-align:left">Christophe Schlick</span>
# <span style="width:49%; display:inline-block; text-align:right">schlick[at]u-bordeaux.fr</span>
# <span style="font-size:48px; font-style:normal"><b>EXERCICES EN TEMPS LIMITÉ</b></span><br>
# <span style="width:49%; display:inline-block; text-align:left">Version 2024-11</span>
# <span style="width:49%; display:inline-block; text-align:right">Licence CC-BY-NC-ND</span></p>

# %% [markdown]
# - **Nom :**                       ......
# - **Prénom :**                    ......
# - **Parcours MAS :**              ......
# - **Salle CREMI :**               ......
# - **Nom du poste :**              ......
# - **URL dossier secret CREMI :**  https://xxx-xxx.emi.u-bordeaux.fr/OI-xxx
# - **URL session ChatGPT :**       https://chatgpt.com/share/xxx

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Instructions pour le démarrage du TP</h3>
#
# Avant de démarrer, procéder aux actions suivantes :
# - Commencez par renommer ce notebook sous la forme **nom.prenom.salle.ipynb**<br>
# Le plus simple est de cliquer sur le nom du notebook dans le **File Browser** à gauche et d'appuyer sur <kbd>F2</kbd>
#
# - Editez la cellule de texte ci-dessus pour remplacer tous les pointillés par les informations vous concernant. Pour l'URL de la session ***ChatGPT***, vous pouvez attendre la fin du TP, lorsque vous aurez créé le lien associé à votre session.
#
# - Exécutez la cellule de code ci-dessous, qui va importer une série de fonctions et de modules qui pourront être utilisés par le code à produire. Il faut noter que tous les imports ne seront pas forcément utiles pour tous les sujets, mais par contre, **aucune autre import ne devra être employé dans le code écrit pour les différents exercices**

# %%
# ------------------------------------------------------------------------------
# ATTENTION : AUCUN AUTRE IMPORT NE SERA AUTORISÉ POUR L'ENSEMBLE DES EXERCICES
# ------------------------------------------------------------------------------
from SRC.tools import load, show
from ipywidgets import interact, interact_manual
from itertools import product, permutations, combinations
import IPython.display as dp

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Informations sur le travail à réaliser</h3>
#
# Ce notebook contient trois exercices de difficulté variable (★ / ★★ / ★★★) qui peuvent être effectués dans un ordre arbitraire. Pour chaque exercice, il s'agit de réaliser une ou deux fonctions devant répondre au problème proposé. Il faut noter qu'à la différence des exercices faits en TD, il n'y a pas d'indication de type **TODO** détaillant la séquence des opérations à implémenter dans les fonctions, c'est à vous de vous débrouiller de manière autonome pour implémenter l'ensemble des fonctionnalités demandées. Le code à fournir pour la plupart des exercices peut s'inspirer; plus ou moins directement, de portions de code se trouvant dans les exemples du cours ou dans les corrigés des exercices, mais là encore, c'est à vous de trouver, à chaque fois, l'exercice qui pourra vous servir de base.
#
# Comme rappelé en cours, les deux critères qualitatifs principaux qui seront utilisés pour la notation sont :
# - le fait de ***produire du code efficace et lisible*** qui utilise des fonctionnalités avancées du langage Python, ainsi que des algorithmes et des structures de données optimisées
# - le fait de ***produire du code capable de se fondre dans le style utilisé pour l'UE*** afin d'avoir l'impression d'un développeur unique pour l'ensemble du code
#
# Pour toute la durée de la séance du TP noté, on vous demande également d'ouvrir une session de travail avec votre compte sur <b>ChatGPT</b>. Il faudra impérativement utiliser une **session non-éphémère** pour pouvoir créer en fin de TP, une URL permettant d'accéder à l'intégralité de votre dialogue avec l'IAG. Je vous rappelle les règles impératives concernant cette session de travail :
#
# - L'ensemble des dialogues avec l'IAG doit ***toujours s'effectuer en anglais***
# - Il faut ***toujours fournir une version alpha du code*** pour les fonctions à écrire, avant de demander l'aide à l'IAG
#
# Pour chaque fonction à écrire, il est donc impératif de mettre dans le notebook, la **version alpha** de la fonction (écrite avant d'utiliser l'IAG) puis la **version finale** de cette fonction, obtenue après dialogue avec l'IAG. ***Les deux zones pour placer les deux versions sont clairement indiquées dans chaque exercice***.
#
# **IMPORTANT :** Même si votre version alpha n'est pas forcément fonctionnelle, ***il faut impérativement qu'elle définisse les différentes variables qui seront nécessaires et qu'elle inclut une ébauche de l'algorithme envisagée***, comme cela, l'IAG pourra facilement corriger ou optimiser votre code en fonction des contraintes que vous allez lui donner.

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Instructions pour la fin du TP</h3>
#
# A la fin du temps imparti, procéder aux actions suivantes :
# - Cliquer sur le bouton **Partager** de votre session ChatGPT pour créer l'URL d'accès pour votre session.
# - Copier l'URL obtenue dans la cellule d'entête de ce notebook
# - Vérifier que vous avez bien renommé le notebook comme indiqué
# - Vérifier que les autres informations demandées dans cette cellule sont bien remplies
# - Recopier le notebook dans le dossier habituel de votre espace ***www*** du CREMI
# - Envoyer un mail à l'adresse **`outinfo@gmx.fr`** avec les informations suivantes :
#   * **Titre du message :** le numéro de la salle où vous êtes
#   * **Contenu du message :** une copie de la cellule d'entête du notebook
#   * **Pièce-jointe au message :** le notebook

# %% [markdown]
# <div style="padding:16px; color:#FFF; background:#F64; font-size:12pt">
#
# <center><h4>Barème des malus appliqués en cas du non-respect des instructions ci-dessus</h4></center>
#
# * Non-respect des modalités du paragraphe "Instructions pour le démarrage du TP" : **-2 points**
# * Non-respect des modalités du paragraphe "Informations pour le travail à réaliser" : **-2 points**
# * Non-respect des modalités du paragraphe "Instructions pour la fin du TP" : **-2 points**
# * Utilisation d'imports de fonctions ou de packages non autorisés : **-2 points par import**
# * Création d'une version alpha par IAG (au travers d'une autre session IAG, en pensant que je ne vais pas le détecter) : **note de 0 pour l'ensemble de l'exercice concerné**
# * Absence de partage de la session IAG : **note de 0 pour l'ensemble de l'exercice concerné**
# </div>

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">B1 - Sélection de pages ★</h2>
#
# Les logiciels de visualisation de PDF permettent à l'utilisateur de choisir d'imprimer uniquement un sous-ensemble de pages, s'il ne souhaite pas imprimer l'intégralité du document. Pour la sélection des pages, un mécanisme standardisé s'est mis en place, utilisable dans la quasi-totalité des logiciels, dans lequel une zone de saisie de texte permet à l'utilisateur de rentrer une séquence mérique combinant des pages isolées ou des tranches de pages consécutives, pour indiquer la sélection des pages et l'ordre dans lequel il souhaite imprimer ces pages. Par exemple, la saisie de :
#
# <center><pre>4-6, 21 - 23, 16 18,,  12-9 , 14</pre></center><br>
#
# va provoquer l'impression des pages **4, 5, 6, 21, 22, 23, 16, 18, 12, 11, 10, 9 et 14** du document courant
#
# Le but de l'exercice est d'écrire une fonction **`pages(selection)`** qui prend en entrée une chaîne de caractères **`selection`** respectant le formalisme précédent et qui renvoie une liste d'entiers correspondant à la séquence de pages sélectionnées. Dans l'idéal, la fonction devra être particulièrement tolérante sur la syntaxe, comme on peut le voir dans l'exemple ci-dessus : l'utilisateur peut mettre des espaces à peu près n'importe où, il peut également omettre les virgules à condition qu'il y ait au moins un espace de séparation entre les nombres, ou au contraire, mettre plusieurs virgules d'affilée. Malgré cette diversité de syntaxe possible, la fonction doit pouvoir identifier correctement la sélection souhaitée. Il faut noter également, que si le terme à droite du signe **`-`** (permettant de spécifier une série de pages consécutives) est plus petit que le terme à gauche, cela signifie que les pages de cette série doivent être sélectionnées par numéros décroissants.

# %% [markdown]
# ### Version alpha de la fonction **`pages`** :

# %%
def pages(selection):
  """return a list of pages from a selection string"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`pages`** :

# %%
def pages(selection):
  """return a list of pages from a selection string"""
  # TODO

# %% [markdown]
# Tester l'implémentation sur les 2 exemples ci-dessous, pour vérifier les résultats obtenus :

# %%
pages('4-6,21-23,16,18,12-9,14') # on doit obtenir [4, 5, 6, 21, 22, 23, 16, 18, 12, 11, 10, 9, 14]

# %%
pages('4-6, 21 - 23, 16 18,,  12-9 , 14') # on doit obtenir la même chose

# %% [markdown]
# ---
# On souhaite rajouter une interface simple avec le module **`ipywidgets`** permettant à l'utilisateur de saisir sa sélection via une zone de saisie et un bouton de validation. Voici une copie d'écran de l'interface souhaitée :
#
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/pages.png" width=480></center>

# %% [markdown]
# ### Version avec interacteur **`ipywidgets`** :

# %%
# TODO

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">B2 - Sortie de labyrinthe par la méthode de Tes ★★</h2>
#
# Un des objectifs de l'exercice C5, à réaliser en travail personnel, est de générer le chemin de longueur minimale reliant l'entrée et la sortie d'un labyrinthe. L'algorithme pour obtenir ce résultat optimal (basé sur l'algorithme récursif de Dijkstra) est relativement complexe à implémenter. Il existe néanmoins un algorithme beaucoup plus simple, appelé **méthode de Tes**, qui peut se résumer par la phrase suivante :
#
# > ***Le marcheur choisit une direction possible (droite ou gauche) à la première intersection rencontrée, puis pour toutes les intersections suivantes, il prend la direction opposée à son choix initial***
#
# Dans le cas des labyrinthes parfaits, comme ceux utilisés dans les exercices B5 et C3, cette méthode permet d'arriver à coup sûr vers la sortie, même si elle ne donne que très rarement le chemin optimal.
#
# Du point de vue algorithmique, il est important de réaliser qu'à tout moment durant son parcours, le marcheur sera défini par trois variables : son indice de ligne **i**, son indice de colonne **j** et sa direction **d** qui peut être représentée par un nombre entier de 0 à 3, numéroté dans le sens horaire : ***0 = Nord, 1 = Est, 2 = Sud, 3 = Ouest***. Ainsi ***tourner à droite*** s'implémente en faisant **`d = (d+1) % 4`** et ***tourner à gauche*** s'obtient en faisant **`d = (d-1) % 4`**. De même, pour gérer les déplacements, il est judicieux de définir une liste **`moves`** regroupant un vecteur de translation pour chacune des quatre directions :
#
# ```moves = [(-1, 0), (0, 1), (1, 0), (0, -1)] # 0 = North, 1 = East, 2 = South, 3 = West```
#
# Avec ces informations, et en utilisant les fichiers de données **`mazeN.txt`** vus en TD, écrire une fonction **`walk_tes(maze)`** qui génère la liste des couples **(i,j)** correspondant aux cases successives parcourues par un marcheur traversant le labyrinthe en utilisant la méthode de Tes :

# %% [markdown]
# ### Version alpha de la fonction **`walk_tes`** :

# %%
def walk_tes(maze):
  """return the path of a walker in provided maze, using the Tes method"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`walk_tes`** :

# %%
def walk_tes(maze):
  """return the path of a walker in provided maze, using the Tes method"""
  # TODO

# %% [markdown]
# Tester la fonction **`walk_tes(maze)`** sur le labyrinthe stocké dans **`maze1.txt`** :

# %%
maze = load('TEST/maze1.txt') # on charge le labyrinthe (modifier éventuellement le chemin)
show("walk_tes(maze)#") # on doit obtenir [(1,0),(1,1),(2,1),(3,1)...(19,18),(19,19),(19,20)]

# %% [markdown]
# Pour visualiser le résultat, on va créer une fonction **`show_walks(maze, walks, scale=8)`** en partant de la fonction **`show_walk`** vue en TD. Au lieu d'avoir un chemin unique **`walk`** à visualiser, la nouvelle fonction prend en paramètre une liste de 2 chemins **`[twalk,walk]`** correspondant respectivement au chemin obtenu en appliquant la méthode de Tes et celui obtenu (optimal) lu dans le fichier **`walkN.txt`**. Les 2 chemins vont être affichés de manière superposée sur la figure : **twalk** en bleu et **walk** en vert. Voici l'image que vous devez obtenir pour les fichiers **`maze1.txt`** et **`walk1.txt`** :
#
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/maze2.png" width=168></center>
#
# Comme on peut le constater, dans le cas de ce labyrinthe, la méthode de Tes fournit un résultat quasi-optimal : seuls quelques couloirs supplémentaires sont parcourus en bleu, par rapport au chemin optimal en vert. En testant la fonction sur d'autres fichiers **`walkN.txt`**, on pourra vérifier que c'est loin d'être toujours le cas :

# %% [markdown]
# ### Version alpha de la fonction **`show_walks`** :

# %%
def show_walks(maze, walks, scale=8):
  """display provided maze and 3 provided walk paths, as an SVG image using 'scale' as scaling factor"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`show_walks`** :

# %%
def show_walks(maze, walks, scale=8):
  """display provided maze and 3 provided walk paths, as an SVG image using 'scale' as scaling factor"""
  # TODO

# %% [markdown]
# Tester la fonction **`show_walks(maze, walks)`** en affichant les 2 chemins obtenus avec le labyrinthe précédent :

# %%
walk = load('TEST/walk1.txt') # on récupère le chemin optimal (modifier éventuellement le chemin)
twalk = [f"{c} {r}" for r,c in walk_tes(maze)] # on convertit dans le format demandé
show_walks(maze, (twalk,walk)) # on doit obtenir un résultat équivalent à l'image fournie

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">B3 - Tic Tac Toe ★★★</h2>
#
# Le [**TicTacToe**](https://fr.wikipedia.org/wiki/Tic-tac-toe) est la version la plus simple des jeux d'alignements (communément appelés ***morpion***) qui se joue à deux joueurs sur une grille 3x3. La simplicité du jeu permet d'énumérer sans difficulté, toutes les configurations possibles pour une partie, et créer ainsi un adversaire virtuel qui va toujours jouer le coup optimal, et ainsi ne pourra jamais perdre.
#
# La configuration d'une grille de TicTacToe peut se représenter par une chaîne de 9 caractères, composée des trois caractères suivants : **`X`**, **`O`** et **`.`** (ce dernier caractère représentant une case vide). Ainsi, les 12 grilles figurant sur l'image ci-dessous, peuvent être encodées par la liste suivante :
# ```
# ['.........' , 'X........' , '.X.......' , '....X....' , 'XO.......' , 'X.O......',
#  'X...O....' , 'X....O...' , 'X.......O' , 'OX.......' , '.X.O.....' , '.X..O....']
# ```
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/tictactoe.png" width=532></center>

# %% [markdown]
# Dans un premier temps, on cherche à énumérer toutes les **configurations uniques et valides** d'une grille de TicTacToe. L'expression "uniques et valides" signifie que l'on ne va pas retenir l'intégralité des grilles possibles mais uniquement celles qui vérifient les propriétés suivantes :
#
# - Le premier joueur est toujours le joueur **`X`**, puis les joueurs alternent leur coup, donc les grilles valides ont forcément, soit le même nombre **`X`** et de **`O`**, soit un nombre de **`X`** supérieur de 1 au nombre de **`O`**
# - La partie s'arrête dès qu'un joueur réalise un alignement (horizontal, vertical ou diagonal) de trois de ses symboles, donc les grilles valides ne peuvent jamais avoir un alignement de **`X`** et un alignement de **`O`** simultanément
# - Une seule configuration est conservée pour toute les grilles qui peuvent s'obtenir à partir d'une autre grille, soit par rotation de 90°, 180° ou 270°, soit par symétrie horizontale ou verticale, soit par combinaison d'une rotation et d'une symétrie. Parmi toutes ces configurations équivalentes, on ne conserve que celle dont la somme des indices des lettres **`X`** et **`O`** est minimale
#
# A partir de ces explications, écrire une fonction **`tictactoe()`** qui renvoie une liste de chaînes de caractères correspondant à toutes les **configurations uniques et valides** d'une grille de TicTacToe. Pour vous guider dans la réalisation, on fournit le code de la fonction lambda **`flip(s)`** permettant d'effectuer une symétrie horizontale sur la grille passée en paramètre. A partir de ce modèle, vous pouvez créer les fonctions lambda **`rot1(s)`**, **`rot2(s)`** et **`rot3(s)`**, appliquant respectivement une rotation de 90°, 180° et 270°, qui vous seront utiles pour écrire le code de la fonction **`tictactoe()`** :

# %%
flip = lambda s: ''.join((s[2],s[1],s[0],s[5],s[4],s[3],s[8],s[7],s[6])) # symétrie horizontale
rot1 = lambda s: 'TODO' # rotation de  90°
rot2 = lambda s: 'TODO' # rotation de 180°
rot3 = lambda s: 'TODO' # rotation de 270°

# %% [markdown]
# ### Version alpha de la fonction **`tictactoe`** :

# %%
def tictactoe():
  """return a list of valid and unique grid configurations for the TicTacToe game"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`tictactoe`** :

# %%
def tictactoe():
  """return a list of valid and unique grid configurations for the TicTacToe game"""
  # TODO

# %% [markdown]
# Normalement, la fonction doit renvoyer une liste de 809 grilles différentes :

# %%
grids = tictactoe()
show("len(grids); grids[:6]; grids[-6:]") # affichage des 6 premières et 6 dernières grilles

# %% [markdown]
# ---
# Pour améliorer la lisibilité, on souhaite afficher l'ensemble des 809 configurations obtenues sous la forme d'une table HTML, en regroupant les grilles par groupes de 6 sur une même ligne. La figure placée au début de l'exercice montre une copie d'écran du résultat souhaité, en se limitant aux 12 premières grilles de la liste. Ecrire la fonction **`show_tictactoe(grids)`** permettant de produire et d'afficher le code HTML correspondant :

# %% [markdown]
# ### Version alpha de la fonction **`show_tictactoe`** :

# %%
def show_tictactoe(grids):
  """display all unique and valid TicTacToe grid configurations, as an HTML table"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`show_tictactoe`** :

# %%
def show_tictactoe(grids):
  """display all unique and valid TicTacToe grid configurations, as an HTML table"""
  # TODO

# %% [markdown]
# Tester la fonction **`show_tictactoe`** pour valider le résultat visuel :

# %%
show_tictactoe(tictactoe()) # on doit obtenir un résultat similaire à l'image fournie mais avec 135 lignes

# %% [markdown]
# <h2 style="padding:0 0 8px; margin:0 -20px; color:#FFF; background:#07D; text-align:right">● ● ●</h3>
