# %% [markdown]
# <p style="color:#FFF; background:#07D; padding:12px; font-size:20px; font-style:italic; text-align:center">
# <span style="width:49%; display:inline-block; text-align:left">Christophe Schlick</span>
# <span style="width:49%; display:inline-block; text-align:right">schlick[at]u-bordeaux.fr</span>
# <span style="font-size:48px; font-style:normal"><b>EXERCICES EN TEMPS LIMITÉ</b></span><br>
# <span style="width:49%; display:inline-block; text-align:left">Version 2024-11</span>
# <span style="width:49%; display:inline-block; text-align:right">Licence CC-BY-NC-ND</span></p>

# %% [markdown]
# - **Nom :**                       ......
# - **Prénom :**                    ......
# - **Parcours MAS :**              ......
# - **Salle CREMI :**               ......
# - **Nom du poste :**              ......
# - **URL dossier secret CREMI :**  https://xxx-xxx.emi.u-bordeaux.fr/OI-xxx
# - **URL session ChatGPT :**       https://chatgpt.com/share/xxx

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Instructions pour le démarrage du TP</h3>
#
# Avant de démarrer, procéder aux actions suivantes :
# - Commencez par renommer ce notebook sous la forme **nom.prenom.salle.ipynb**<br>
# Le plus simple est de cliquer sur le nom du notebook dans le **File Browser** à gauche et d'appuyer sur <kbd>F2</kbd>
#
# - Editez la cellule de texte ci-dessus pour remplacer tous les pointillés par les informations vous concernant. Pour l'URL de la session ***ChatGPT***, vous pouvez attendre la fin du TP, lorsque vous aurez créé le lien associé à votre session.
#
# - Exécutez la cellule de code ci-dessous, qui va importer une série de fonctions et de modules qui pourront être utilisés par le code à produire. Il faut noter que tous les imports ne seront pas forcément utiles pour tous les sujets, mais par contre, **aucune autre import ne devra être employé dans le code écrit pour les différents exercices**

# %%
# ------------------------------------------------------------------------------
# ATTENTION : AUCUN AUTRE IMPORT NE SERA AUTORISÉ POUR L'ENSEMBLE DES EXERCICES
# ------------------------------------------------------------------------------
from SRC.tools import load, show
from ipywidgets import interact, interact_manual
from itertools import product, permutations, combinations
import IPython.display as dp

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Informations sur le travail à réaliser</h3>
#
# Ce notebook contient trois exercices de difficulté variable (★ / ★★ / ★★★) qui peuvent être effectués dans un ordre arbitraire. Pour chaque exercice, il s'agit de réaliser une ou deux fonctions devant répondre au problème proposé. Il faut noter qu'à la différence des exercices faits en TD, il n'y a pas d'indication de type **TODO** détaillant la séquence des opérations à implémenter dans les fonctions, c'est à vous de vous débrouiller de manière autonome pour implémenter l'ensemble des fonctionnalités demandées. Le code à fournir pour la plupart des exercices peut s'inspirer; plus ou moins directement, de portions de code se trouvant dans les exemples du cours ou dans les corrigés des exercices, mais là encore, c'est à vous de trouver, à chaque fois, l'exercice qui pourra vous servir de base.
#
# Comme rappelé en cours, les deux critères qualitatifs principaux qui seront utilisés pour la notation sont :
# - le fait de ***produire du code efficace et lisible*** qui utilise des fonctionnalités avancées du langage Python, ainsi que des algorithmes et des structures de données optimisées
# - le fait de ***produire du code capable de se fondre dans le style utilisé pour l'UE*** afin d'avoir l'impression d'un développeur unique pour l'ensemble du code
#
# Pour toute la durée de la séance du TP noté, on vous demande également d'ouvrir une session de travail avec votre compte sur <b>ChatGPT</b>. Il faudra impérativement utiliser une **session non-éphémère** pour pouvoir créer en fin de TP, une URL permettant d'accéder à l'intégralité de votre dialogue avec l'IAG. Je vous rappelle les règles impératives concernant cette session de travail :
#
# - L'ensemble des dialogues avec l'IAG doit ***toujours s'effectuer en anglais***
# - Il faut ***toujours fournir une version alpha du code*** pour les fonctions à écrire, avant de demander l'aide à l'IAG
#
# Pour chaque fonction à écrire, il est donc impératif de mettre dans le notebook, la **version alpha** de la fonction (écrite avant d'utiliser l'IAG) puis la **version finale** de cette fonction, obtenue après dialogue avec l'IAG. ***Les deux zones pour placer les deux versions sont clairement indiquées dans chaque exercice***.
#
# **IMPORTANT :** Même si votre version alpha n'est pas forcément fonctionnelle, ***il faut impérativement qu'elle définisse les différentes variables qui seront nécessaires et qu'elle inclut une ébauche de l'algorithme envisagée***, comme cela, l'IAG pourra facilement corriger ou optimiser votre code en fonction des contraintes que vous allez lui donner.

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Instructions pour la fin du TP</h3>
#
# A la fin du temps imparti, procéder aux actions suivantes :
# - Cliquer sur le bouton **Partager** de votre session ChatGPT pour créer l'URL d'accès pour votre session.
# - Copier l'URL obtenue dans la cellule d'entête de ce notebook
# - Vérifier que vous avez bien renommé le notebook comme indiqué
# - Vérifier que les autres informations demandées dans cette cellule sont bien remplies
# - Recopier le notebook dans le dossier habituel de votre espace ***www*** du CREMI
# - Envoyer un mail à l'adresse **`outinfo@gmx.fr`** avec les informations suivantes :
#   * **Titre du message :** le numéro de la salle où vous êtes
#   * **Contenu du message :** une copie de la cellule d'entête du notebook
#   * **Pièce-jointe au message :** le notebook

# %% [markdown]
# <div style="padding:16px; color:#FFF; background:#F64; font-size:12pt">
#
# <center><h4>Barème des malus appliqués en cas du non-respect des instructions ci-dessus</h4></center>
#
# * Non-respect des modalités du paragraphe "Instructions pour le démarrage du TP" : **-2 points**
# * Non-respect des modalités du paragraphe "Informations pour le travail à réaliser" : **-2 points**
# * Non-respect des modalités du paragraphe "Instructions pour la fin du TP" : **-2 points**
# * Utilisation d'imports de fonctions ou de packages non autorisés : **-2 points par import**
# * Création d'une version alpha par IAG (au travers d'une autre session IAG, en pensant que je ne vais pas le détecter) : **note de 0 pour l'ensemble de l'exercice concerné**
# * Absence de partage de la session IAG : **note de 0 pour l'ensemble de l'exercice concerné**
# </div>

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">A1 - Affichage d'un échiquier ★</h2>
#
# Comme on l'a rappelé dans le chapitre 3, la norme Unicode définit une grande variété de caractères typographiques, regroupés par catégories. Ainsi, entre les indices hexadécimaux **2654** et **265F** se trouve un jeu de caractères appelé [**chess-symbols**](https://citizendium.org/wiki/Chess_symbols_in_Unicode) qui est destiné à l'affichage des pièces du [**jeu d'échecs**](https://en.wikipedia.org/wiki/Rules_of_chess#Initial_setup) comme le montre le code suivant :

# %%
print(' '.join(chr(n) for n in range(0x2654,0x2660))) # unicode 'chess-symbols' charset

# %% [markdown]
# L'objectif de l'exercice est d'écrire une fonction **`show_chess()`** qui permet d'afficher un échiquier,  sous la forme d'une table HTML utilisant ce jeu de caractères. La table doit inclure :
#
# - **au centre :** les 64 cases de l'échiquier avec la position de départ des différentes pièces
# - **à droite et à gauche :** la numérotation des lignes de l'échiquier (nombres entre 1 et 8)
# - **en haut et en bas :** la numérotation des colonnes de l'échiquier (lettres entre A et H)
#
# Voici une copie d'écran du résultat souhaité :
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/chess.png" width="384"></center>

# %% [markdown]
# ### Version alpha de la fonction **`show_chess`** :

# %%
def show_chess():
  """display the initial setup of a chessboard as an HTML table, using unicode chess symbols"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`show_chess`** :

# %%
def show_chess():
  """display the initial setup of a chessboard as an HTML table, using unicode chess symbols"""
  # TODO

# %% [markdown]
# Tester la fonction **`show_chess`** pour valider le résultat visuel :

# %%
show_chess() # on doit obtenir un résultat équivalent à l'image fournie

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">A2 - Sortie de labyrinthe par la méthode de la main droite ★★</h2>
#
# Un des objectifs de l'exercice C5, à réaliser en travail personnel, est de générer le chemin de longueur minimale reliant l'entrée et la sortie d'un labyrinthe. L'algorithme pour obtenir ce résultat optimal (basé sur l'algorithme récursif de Dijkstra) est relativement complexe à implémenter. Il existe néanmoins un algorithme beaucoup plus simple, appelé **méthode de la main droite**, qui peut se résumer par la phrase suivante :
#
# > ***Le marcheur entre dans le labyrinthe en touchant, avec sa main, le mur à sa droite, et va suivre uniquement le chemin qui lui permet de ne jamais rompre le contact avec ce mur de droite***
#
# Dans le cas des labyrinthes parfaits, comme ceux utilisés dans les exercices B5 et C3, cette méthode permet d'arriver à coup sûr vers la sortie, même si elle ne donne que très rarement le chemin optimal. Il existe également un algorithme dual, appelé **méthode de la main gauche**, qui fonctionne de manière équivalente en gardant le contact avec le mur de gauche, depuis l'entrée jusqu'à la sortie du labyrinthe.
#
# Du point de vue algorithmique, il est important de réaliser qu'à tout moment durant son parcours, le marcheur sera défini par trois variables : son indice de ligne **i**, son indice de colonne **j** et sa direction **d** qui peut être représentée par un nombre entier de 0 à 3, numéroté dans le sens horaire : ***0 = Nord, 1 = Est, 2 = Sud, 3 = Ouest***. Ainsi ***tourner à droite*** s'implémente en faisant **`d = (d+1) % 4`** et ***tourner à gauche*** s'obtient en faisant **`d = (d-1) % 4`**. De même, pour gérer les déplacements, il est judicieux de définir une liste **`moves`** regroupant un vecteur de translation pour chacune des quatre directions :
#
# ```moves = [(-1, 0), (0, 1), (1, 0), (0, -1)] # 0 = North, 1 = East, 2 = South, 3 = West```
#
# On comparant les algorithmes implémentant la méthode de la main droite et celle de la main gauche, on s'aperçoit que les codes sont quasiment identiques. La seule chose qui change est que chaque fois que la méthode de la main droite fait un +1, celle de la main gauche fait un -1, et vice versa. Ce qui signifie qu'on peut implémenter les deux techniques dans une même fonction, en rajoutant simplement un paramètre pour distinguer les deux versions. Avec toutes ces informations, et en utilisant les fichiers de données **`mazeN.txt`** vus en TD, écrire une fonction **`walk_hand(maze, hand=1)`** qui génère la liste des couples **(i,j)** correspondant aux cases successives parcourues par un marcheur traversant le labyrinthe en utilisant la méthode de la main droite lorsque **`hand=1`**, ou celle de la main gauche lorsque **`hand=-1`** :

# %% [markdown]
# ### Version alpha de la fonction **`walk_hand`** :

# %%
def walk_hand(maze, hand=1):
  """return the path of a walker in provided maze, using either right hand or left hand method"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`walk_hand`** :

# %%
def walk_hand(maze, hand=1):
  """return the path of a walker in provided maze, using either right hand or left hand method"""
  # TODO

# %% [markdown]
# Tester la fonction **`walk_hand(maze, hand)`** sur le labyrinthe stocké dans **`maze0.txt`** :

# %%
maze = load('TEST/maze0.txt') # on charge le labyrinthe (modifier éventuellement le chemin)
show("walk_hand(maze, 1)#") # on doit obtenir [(1,0),(1,1),(2,1),(3,1),(4,1)...(13,12),(13,13),(13,14)]
show("walk_hand(maze,-1)#") # on doit obtenir [(1,0),(1,1),(1,2),(1,3),(2,3)...(12,13),(13,13),(13,14)]

# %% [markdown]
# Pour visualiser le résultat, on va créer une fonction **`show_walks(maze, walks, scale=8)`** en partant de la fonction **`show_walk`** vue en TD. Au lieu d'avoir un chemin unique **`walk`** à visualiser, la nouvelle fonction prend en paramètre une liste de 3 chemins **`[rwalk,lwalk,walk]`** correspondant respectivement au chemin obtenu en appliquant l'algorithme ***main droite***, celui obtenu en appliquant l'algorithme ***main gauche*** et celui (optimal) lu dans le fichier **`walkN.txt`**. Les 3 chemins vont être affichés de manière superposés sur le labyrinthe : **rwalk** en bleu, **lwalk** en rouge et **walk** en vert. Voici l'image que vous devez obtenir en utilisant les fichiers **`maze0.txt`** et **`walk0.txt`** :
#
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/maze1.png" width=128></center>

# %% [markdown]
# ### Version alpha de la fonction **`show_walks`** :

# %%
def show_walks(maze, walks, scale=8):
  """display provided maze and 3 provided walk paths, as an SVG image using 'scale' as scaling factor"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`show_walks`** :

# %%
def show_walks(maze, walks, scale=8):
  """display provided maze and 3 provided walk paths, as an SVG image using 'scale' as scaling factor"""
  # TODO

# %% [markdown]
# Tester la fonction **`show_walks(maze, walks)`** en affichant les 3 chemins obtenus avec le labyrinthe précédent :

# %%
walk = load('TEST/walk0.txt') # on récupère le chemin optimal (modifier éventuellement le chemin)
rwalk = [f"{c} {r}" for r,c in walk_hand(maze, 1)] # on convertit dans le format demandé
lwalk = [f"{c} {r}" for r,c in walk_hand(maze,-1)] # on convertit dans le format demandé
show_walks(maze, (rwalk,lwalk,walk)) # on doit obtenir un résultat équivalent à l'image fournie

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">A3 - Anagrammeur ★★★</h2>
#
# Le but de l'exercice est de réaliser un [**anagrammeur**](https://www.anagrammeur.com), un logiciel capable de trouver tous les anagrammes d'un groupe de lettres données par l'utilisateur. Pour cela, on fournit le fichier [**dicoScrabbleFRA.txt**](https://www.labri.fr/perso/schlick/outinfo/!!!/dicoScrabbleFRA.txt) correspondant au ***Dictionnaire Officiel du Scrabble*** contenant tous les mots de la langue française, sauf les mots d'une seule lettre, les noms propres et les abbréviations, trois familles de mots qui sont interdits dans la quasi-totalité des jeux de lettres. A la différence d'un dictionnaire usuel, cette liste contient également toutes les formes conjuguées des verbes, ainsi que les déclinaisons (masculin singulier, féminin singulier, masculin pluriel, féminin pluriel) pour les noms et les adjectifs. Grâce à la fonction **`load`** vue en cours, on peut facilement récupérer cette liste de mots pour la stocker dans une variable **`words`** qui contiendra **386264 mots** comme on peut le voir ci-dessous :

# %%
words = load('https://www.labri.fr/perso/schlick/outinfo/!!!/dicoScrabbleFRA.txt')
print(f"Nb words = {len(words)}") # 386264 mots différents dans le dictionnaire
print(' '.join(words[:4]), '...', ' '.join(words[-4:])) # affiche les 4 premiers et 4 derniers mots

# %% [markdown]
# ---
# La première étape consiste à réorganiser cette liste de mots, afin de regrouper tous les mots étant des anagrammes les uns des autres. Pour cela, le plus simple est d'associer à chaque mot, une **clé** définie en classant les lettres de ce mot par ordre alphabétique, ainsi deux mots ayant les mêmes lettres auront évidemment la même clé. Utiliser cette idée pour créer un dictionnaire **`anagrams`** contenant tous les mots de la liste **`words`**, dans lequel les clés sont définies par la chaîne de caractères correspondant aux lettres ordonnées, et les valeurs sont définies par une chaîne de caractères regroupant tous les mots ayant les mêmes lettres que la clé, séparés par le caractère **`/`**. A titre d'illustration, voici deux éléments qui seront stockées dans ce dictionnaire **`anagrams`** :
# ```
# anagrams['EEILOST'] ➤ ETIOLES/ETOILES/OISELET/TOILEES
# anagrams['AEEIMNS'] ➤ AMINEES/AMNESIE/ANEMIES/ANIMEES/MANIEES/SEMAINE
# ```

# %%
anagrams = 'TODO'

# %% [markdown]
# Vérifier votre implémentation sur les deux exemples précédents :

# %%
show("anagrams['EEILOST']; anagrams['AEEIMNS']")

# %% [markdown]
# ---
# La seconde étape consiste à écrire la fonction **`anagram(chars, anagrams)`** qui prend en paramètres la séquence de caractères **`chars`** ainsi que le dictionnaire **`anagrams`** généré ci-dessus, et qui doit retourner tous les anagrammes de **`chars`**. Lorsque la séquence de caractères est un peu longue (typiquement lorsqu'on donne deux mots ou carrément toute une phrase), il est très rare d'obtenir un anagramme complet. Pour augmenter la variété des réponses fournies, il est donc demandé d'énumérer toutes les manières de partitionner la séquence **`chars`** en deux sous-ensembles disjoints, et de trouver les anagrammes pour chacun de ces sous-ensembles. Par exemple, voici ce que doit renvoyer la fonction lorsqu'elle est appelée avec la chaîne **`'langage python'`** comme séquence de caractères :
#
# ```
# anagram('langage python', anagrams) ➤
# ANAGLYPHE + TONG
# AGLYPHE + TANGON/TONGAN
# GLANAGE/LANGAGE + PYTHON/TYPHON
# GLANANT + HYPOGE
# ```
#
# Dans cet exemple, on peut voir que les anagrammes sont classés par tailles décroissantes du mot le plus long, puis par ordre alphabétique lorsque les mots ont la même taille. Mais on peut également mettre en oeuvre, un tri alphabétique global, indépendamment de la longueur des mots, ce qui sera plus simple à implémenter.

# %% [markdown]
# ### Version alpha de la fonction **`anagram`** :

# %%
def anagram(chars, anagrams):
  """find all anagrams for provided chars, using one or two words from the anagrams dictionary"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`anagram`** :

# %%
def anagram(chars, anagrams):
  """find all anagrams for provided chars, using one or two words from the anagrams dictionary"""
  # TODO

# %% [markdown]
# Tester la fonction **`anagram(chars, anagrams)`** sur la chaîne **`'langage python'`** :

# %%
show("anagram('langage python')#") # on doit obtenir le résultat indiqué plus haut

# %% [markdown]
# ---
# Enfin, on souhaite rajouter une interface simple avec le module **`ipywidgets`** permettant à l'utilisateur de saisir sa séquence de caractères via une zone de saisie et un bouton de validation. Voici une copie d'écran de l'interface souhaitée :
#
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/anagram.png" width=320></center>

# %% [markdown]
# ### Version avec interacteur **`ipywidgets`** :

# %%
# TODO

# %% [markdown]
# <h2 style="padding:0 0 8px; margin:0 -20px; color:#FFF; background:#07D; text-align:right">● ● ●</h3>
