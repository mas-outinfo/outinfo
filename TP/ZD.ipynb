# %% [markdown]
# <p style="color:#FFF; background:#07D; padding:12px; font-size:20px; font-style:italic; text-align:center">
# <span style="width:49%; display:inline-block; text-align:left">Christophe Schlick</span>
# <span style="width:49%; display:inline-block; text-align:right">schlick[at]u-bordeaux.fr</span>
# <span style="font-size:48px; font-style:normal"><b>EXERCICES EN TEMPS LIMITÉ</b></span><br>
# <span style="width:49%; display:inline-block; text-align:left">Version 2024-11</span>
# <span style="width:49%; display:inline-block; text-align:right">Licence CC-BY-NC-ND</span></p>

# %% [markdown]
# - **Nom :**                       ......
# - **Prénom :**                    ......
# - **Parcours MAS :**              ......
# - **Salle CREMI :**               ......
# - **Nom du poste :**              ......
# - **URL dossier secret CREMI :**  https://xxx-xxx.emi.u-bordeaux.fr/OI-xxx
# - **URL session ChatGPT :**       https://chatgpt.com/share/xxx

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Instructions pour le démarrage du TP</h3>
#
# Avant de démarrer, procéder aux actions suivantes :
# - Commencez par renommer ce notebook sous la forme **nom.prenom.salle.ipynb**<br>
# Le plus simple est de cliquer sur le nom du notebook dans le **File Browser** à gauche et d'appuyer sur <kbd>F2</kbd>
#
# - Editez la cellule de texte ci-dessus pour remplacer tous les pointillés par les informations vous concernant. Pour l'URL de la session ***ChatGPT***, vous pouvez attendre la fin du TP, lorsque vous aurez créé le lien associé à votre session.
#
# - Exécutez la cellule de code ci-dessous, qui va importer une série de fonctions et de modules qui pourront être utilisés par le code à produire. Il faut noter que tous les imports ne seront pas forcément utiles pour tous les sujets, mais par contre, **aucune autre import ne devra être employé dans le code écrit pour les différents exercices**

# %%
# ------------------------------------------------------------------------------
# ATTENTION : AUCUN AUTRE IMPORT NE SERA AUTORISÉ POUR L'ENSEMBLE DES EXERCICES
# ------------------------------------------------------------------------------
from SRC.tools import load, show
from ipywidgets import interact, interact_manual
from itertools import product, permutations, combinations
import IPython.display as dp

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Informations sur le travail à réaliser</h3>
#
# Ce notebook contient trois exercices de difficulté variable (★ / ★★ / ★★★) qui peuvent être effectués dans un ordre arbitraire. Pour chaque exercice, il s'agit de réaliser une ou deux fonctions devant répondre au problème proposé. Il faut noter qu'à la différence des exercices faits en TD, il n'y a pas d'indication de type **TODO** détaillant la séquence des opérations à implémenter dans les fonctions, c'est à vous de vous débrouiller de manière autonome pour implémenter l'ensemble des fonctionnalités demandées. Le code à fournir pour la plupart des exercices peut s'inspirer; plus ou moins directement, de portions de code se trouvant dans les exemples du cours ou dans les corrigés des exercices, mais là encore, c'est à vous de trouver, à chaque fois, l'exercice qui pourra vous servir de base.
#
# Comme rappelé en cours, les deux critères qualitatifs principaux qui seront utilisés pour la notation sont :
# - le fait de ***produire du code efficace et lisible*** qui utilise des fonctionnalités avancées du langage Python, ainsi que des algorithmes et des structures de données optimisées
# - le fait de ***produire du code capable de se fondre dans le style utilisé pour l'UE*** afin d'avoir l'impression d'un développeur unique pour l'ensemble du code
#
# Pour toute la durée de la séance du TP noté, on vous demande également d'ouvrir une session de travail avec votre compte sur <b>ChatGPT</b>. Il faudra impérativement utiliser une **session non-éphémère** pour pouvoir créer en fin de TP, une URL permettant d'accéder à l'intégralité de votre dialogue avec l'IAG. Je vous rappelle les règles impératives concernant cette session de travail :
#
# - L'ensemble des dialogues avec l'IAG doit ***toujours s'effectuer en anglais***
# - Il faut ***toujours fournir une version alpha du code*** pour les fonctions à écrire, avant de demander l'aide à l'IAG
#
# Pour chaque fonction à écrire, il est donc impératif de mettre dans le notebook, la **version alpha** de la fonction (écrite avant d'utiliser l'IAG) puis la **version finale** de cette fonction, obtenue après dialogue avec l'IAG. ***Les deux zones pour placer les deux versions sont clairement indiquées dans chaque exercice***.
#
# **IMPORTANT :** Même si votre version alpha n'est pas forcément fonctionnelle, ***il faut impérativement qu'elle définisse les différentes variables qui seront nécessaires et qu'elle inclut une ébauche de l'algorithme envisagée***, comme cela, l'IAG pourra facilement corriger ou optimiser votre code en fonction des contraintes que vous allez lui donner.

# %% [markdown]
# <h3 style="padding:16px; color:#FFF; background:#07D">Instructions pour la fin du TP</h3>
#
# A la fin du temps imparti, procéder aux actions suivantes :
# - Cliquer sur le bouton **Partager** de votre session ChatGPT pour créer l'URL d'accès pour votre session.
# - Copier l'URL obtenue dans la cellule d'entête de ce notebook
# - Vérifier que vous avez bien renommé le notebook comme indiqué
# - Vérifier que les autres informations demandées dans cette cellule sont bien remplies
# - Recopier le notebook dans le dossier habituel de votre espace ***www*** du CREMI
# - Envoyer un mail à l'adresse **`outinfo@gmx.fr`** avec les informations suivantes :
#   * **Titre du message :** le numéro de la salle où vous êtes
#   * **Contenu du message :** une copie de la cellule d'entête du notebook
#   * **Pièce-jointe au message :** le notebook

# %% [markdown]
# <div style="padding:16px; color:#FFF; background:#F64; font-size:12pt">
#
# <center><h4>Barème des malus appliqués en cas du non-respect des instructions ci-dessus</h4></center>
#
# * Non-respect des modalités du paragraphe "Instructions pour le démarrage du TP" : **-2 points**
# * Non-respect des modalités du paragraphe "Informations pour le travail à réaliser" : **-2 points**
# * Non-respect des modalités du paragraphe "Instructions pour la fin du TP" : **-2 points**
# * Utilisation d'imports de fonctions ou de packages non autorisés : **-2 points par import**
# * Création d'une version alpha par IAG (au travers d'une autre session IAG, en pensant que je ne vais pas le détecter) : **note de 0 pour l'ensemble de l'exercice concerné**
# * Absence de partage de la session IAG : **note de 0 pour l'ensemble de l'exercice concerné**
# </div>

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">D1 - Dames anglaises, françaises, canadiennes, ... ★</h2>
#
# Le [**jeu de Dames**](https://fr.wikipedia.org/wiki/Dames#Les_variantes_nationales) est un jeu de réflexion sur plateau à deux joueurs, mettant en oeuvre ***n(n-1)*** pions par joueur, ces pions étant répartis sur les cases blanches d'un damier de taille ***2n x 2n***. Le but du jeu est de prendre l'intégralité des pions du joueur adverse, sachant que les règles de prise et de déplacement, varient légèrement selon les variantes. Le plateau de jeu peut se construire pour une valeur quelconque de ***n > 1***, mais les trois variantes les plus connues utilisent les valeurs :
#
# * ***n = 4*** (soit 12 pions par joueur, sur un damier 8x8) appelée **Dames Anglaises**
# * ***n = 5*** (soit 20 pions par joueur, sur un damier 10x10) appelée **Dames Françaises**
# * ***n = 6*** (soit 30 pions par joueurs, sur un damier 12x12) appelée **Dames Canadiennes**
# </ul>
#
# La figure ci-dessous montre la position de départ des pions, pour la variante des **Dames anglaises**. La configuration initiale des autres variantes est parfaitement similaire : les pions de chaque joueur sont répartis sur les cases blanches d'une zone de ***n-1*** lignes contenant ***n*** pions chacune.
#
# En s'inspirant de la fonction **`chessboard`** vue dans le chapitre 4 du cours, écrire une fonction **`show_checkers(n=4, scale=32, colors='#EEE #777 #F80 #08F')`** qui va générer le code SVG pour afficher  la configuration de départ d'un damier. Le paramètre ***n*** (compris entre 2 et 10) permet de définir la variante du damier à générer, le paramètre **`scale`** correspond au facteur d'échelle pour les cases, et le paramètre **`colors`** aux quatre couleurs utilisées pour le damier (dans l'ordre, couleur des cases claires, des cases sombres, des pions du haut et enfin, des pions du bas).
#
# Voici une copie d'écran du résultat que doit fournir **`show_checkers`** avec les valeurs par défaut :
#
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/checkers.png" width=256></center>

# %% [markdown]
# ### Version alpha de la fonction **`show_checkers`** :

# %%
def show_checkers(n=4, scale=32, colors='#EEE #777 #F80 #08F'):
  """display a checkerboard as an SVG image, using provided size, scale factor and colors"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`show_checkers`** :

# %%
def show_checkers(n=4, scale=32, colors='#EEE #777 #F80 #08F'):
  """display a checkerboard as an SVG image, using provided size, scale factor and colors"""
  # TODO

# %% [markdown]
# Tester la fonction **`show_checkers`** pour valider le résultat visuel :

# %%
show_checkers() # on doit obtenir un résultat équivalent à l'image fournie

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">D2 - Spirale d'Ulam ★★</h2>
#
# La [**spirale d'Ulam**](https://fr.wikipedia.org/wiki/Spirale_d%27Ulam) est une observation expérimentale, découverte de manière fortuite par Stanislaw Ulam en 1963. Il s'agit d'un résultat visuel obtenu en écrivant les entiers naturels en spirale dans un grille et en coloriant toutes les cases contenant des nombres premiers. Comme le montre la figure ci-dessous, les cases coloriées dans cette spirale vont exhiber de manière très nette des lignes horizontales, verticales et surtout diagonales, qui laisse à penser à une organisation semi-régulière des nombres premiers au sein des nombres naturels. Mais à ce jour, il n'existe pas d'explication mathématique permettant de justifier l'origine de ces alignements semi-réguliers.
#
# L'objectif de l'exercice est d'écrire une fonction **`show_ulam(n)`** qui permet d'afficher la spirale d'Ulam jusqu'à la valeur $n^2$, sous la forme d'une table HTML en coloriant en rouge toutes les cases contenant des nombres premiers. L'implémentation sera basée sur l'emploi de la fonction **`prime_eratos(n)`** de l'exercice B2. Voici une copie d'écran du résultat souhaité :
#
# <center><img src="https://www.labri.fr/perso/schlick/outinfo/!!!/ulam.png" width=532></center>

# %% [markdown]
# ### Version alpha de la fonction **`show_ulam`** :

# %%
def show_ulam(n=15):
  """display the Ulam spiral up to n*n, as an HTML table (red cells for primes, white for non-primes)"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`show_ulam`** :

# %%
def show_ulam(n=15):
  """display the Ulam spiral up to n*n, as an HTML table (red cells for primes, white for non-primes)"""
  # TODO

# %% [markdown]
# Tester la fonction **`show_ulam`** pour valider le résultat visuel :

# %%
show_ulam(25) # on doit obtenir un résultat équivalent à l'image fournie

# %% [markdown]
# <h2 style="padding:16px; color:#FFF; background:#07D">D3 - Boggle, Big Boggle et Super Boggle ★★★</h2>
#
# Le [**Boggle**](https://fr.wikipedia.org/wiki/Boggle) est un jeu de société, dans la famille des [**jeux de lettres**](https://fr.wikipedia.org/wiki/Jeu_de_lettres), dans lequel les joueurs doivent trouver le maximum de mots, en combinant des lettres adjacentes dans une grille 4x4 (cf. image sur le lien Wikipedia ci-dessus). Chaque case de la grille est composée d'un dé à 6 faces, contenant une lettre par face qui sont sélectionnées indépendamment et aléatoirement en secouant la boîte de jeu. La répartition des 96 lettres figurant sur les 16 dés est indiquée sur la page Wikipedia, et cette répartition est utilisée pour créer la  variable **`boggle`**, ci-dessous :

# %%
boggle = [ # on extrait la composition des 16 dés à partir de la page Wikipedia
  'ETUKNO','EVGTIN','DECAMP','IELRUW','EHIFSE','RECALS','ENTDOS','OFXRIA',
  'NAVEDZ','EIOATA','GLENYU','BMAQJO','TLIBRA','SPULTE','AIMSOR','ENHRIS']
boggle = ''.join(sorted(''.join(boggle))) # on trie les 96 lettres par ordre alphabétique
show("boggle")

# %% [markdown]
# Le but de cet exercice, est de vérifier si la répartition des lettres, telle qu'elle est définie par les dés du **Boggle**, est conforme à la distribution statistique des lettres dans les mots de la langue française, et si ce n'est pas le cas, d'en proposer une meilleure, plus proche de cette distribution.
#
# Pour cela, on fournit le fichier [**dicoScrabbleFRA.txt**](https://www.labri.fr/perso/schlick/outinfo/!!!/dicoScrabbleFRA.txt) correspondant au ***Dictionnaire Officiel du Scrabble*** contenant tous les mots de la langue française, sauf les mots d'une seule lettre, les noms propres et les abbréviations qui sont interdits dans la quasi-totalité des jeux de lettres. A la différence d'un dictionnaire usuel, cette liste contient également toutes les formes conjuguées des verbes, ainsi que les déclinaisons (masculin singulier, féminin singulier, masculin pluriel, féminin pluriel) pour les noms et les adjectifs. Grâce à la fonction **`load`** vue en cours, on peut facilement récupérer cette liste de mots pour la stocker dans une variable **`words`** que l'on fusionnera dans une chaîne unique, appelée **`chars`**. Comme on peut le voir ci-dessous, la liste comporte **386264 mots** différents, avec un total de **3867567 lettres** utilisées :

# %%
words = load('https://www.labri.fr/perso/schlick/outinfo/CSV/dicoScrabbleFRA.txt')
print(f"Nb words = {len(words)}") # 386264 mots différents dans le dictionnaire
print(' '.join(words[:4]), '...', ' '.join(words[-4:])) # 4 premiers et 4 derniers mots

chars = ''.join(words) # on fusionne tous les mots en une chaîne unique
print(f"Nb chars = {len(chars)}") # 3867567 lettres
print(chars[:20], '...', chars[-20:]) # 20 premières et 20 dernières lettres

# %% [markdown]
# ---
# La distribution des 26 lettres dans la variable **`chars`** représente la distribution idéale que devrait avoir tout jeu de lettres en langue française. Mais comme on peut le constater facilement, la fréquence d'apparition de certaines lettres rares (par exemple, **K**, **W** ou **Y**) est bien inférieure à 1/96, ce qui signifie que si l'on respecte cette distribution de manière stricte, ces lettres rares ne devraient pas figurer parmi les 96 lettres utilisées par le Boogle. Or tous les jeux de lettres vont inclure systématiquement l'ensemble des 26 lettres de l'alphabet, il y aura donc forcément un écart entre la distribution effective des lettres utilisées par ces jeux, et la distribution idéale des lettres dans la langue française. L'outil habituellement utilisé en statistiques pour mesurer l'écart entre deux distributions est le [**test du Khi-2**](https://fr.wikipedia.org/wiki/Test_du_%CF%87%C2%B2). Pour simplifier l'implémentation, nous allons simplement calculer [**l'erreur quadratique moyenne**](https://en.wikipedia.org/wiki/Mean_squared_error) (*Mean Squared Error* ou ***MSE*** en anglais) qui est l'une des étapes du test du Khi-2, et qui sera suffisante pour comparer et classer les différentes distributions.
#
# Ecrire une fonction **`mse_chardist(distA, distB)`** qui calcule l'erreur quadratique moyenne entre deux distribution de lettres fournies sous la forme de chaînes de caractères. Comme les deux distributions n'ont pas forcément la même longueur (c'est clairement le cas ici, puisque **`boggle`** contient 96 lettres et **`chars`** en contient plus de 3.8 millions), il faut évidemment ***normaliser les histogrammes*** avant de calculer la valeur de l'erreur quadratique :

# %% [markdown]
# ### Version alpha de la fonction **`mse_chardist`** :

# %%
def mse_chardist(distA, distB):
  """return Mean Squared Error between two char distributions provided as strings"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`mse_chardist`** :

# %%
def mse_chardist():
  """return Mean Squared Error between two char distributions provided as strings"""
  # TODO

# %% [markdown]
# Tester la fonction sur la chaîne **`boggle`** définie plus haut :

# %%
mse = mse_chardist(boggle, chars)
show("boggle; mse") # on doit obtenir 0.0035406899434759975 (ou pas loin)

# %% [markdown]
# ---
# A partir de ces éléments, écrire une fonction **`optimal_dist(chars, n=96)`** qui retourne une chaîne de 96 caractères correspondant à la distribution optimale des lettres du Boggle par rapport à la distribution idéale stockée dans **`chars`**, sachant que l'on force la distribution à avoir au moins un exemplaire de chacune des 26 lettres de l'alphabet. Il existe plusieurs manières d'obtenir cette distribution optimale, selon que vous prenez une approche déterministe ou stochastique :

# %% [markdown]
# ### Version alpha de la fonction **`optimal_dist`** :

# %%
def optimal_dist(chars, n=96):
  """generate optimal distribution of 'n' letters, using 'chars' as the reference distribution"""
  # TODO

# %% [markdown]
# ### Version finale de la fonction **`optimal_dist`** :

# %%
def optimal_dist(chars, n=96):
  """generate optimal distribution of 'n' letters, using 'chars' as the reference distribution"""
  # TODO

# %% [markdown]
# Utiliser la fonction pour obtenir les 96 caractères nécessaires pour le Boggle, et vérifier que l'erreur quadratique moyenne est bien inférieure à celle donnée par la répartition "officielle" stockée dans la variable **`boggle`** :

# %%
dist = optimal_dist(chars, 96) # recherche de la distribution optimale
mse = mse_chardist(dist, chars) # calcul de l'erreur quadratique moyenne
show("dist; mse") # on doit obtenir 0.0007556512957400093 (ou pas loin)

# %% [markdown]
# ---
# Le jeu du Boggle existe également en 2 autres variantes : le **Big Boggle** qui utilise 25 dés répartis sur une grille 5x5 (donc 150 lettres au total) et le **Super Boggle** qui utilise 36 dés répartis sur une  grille 6x6 (donc 216 lettres). Si votre fonction est bien écrite, vous devriez trouver, sans modification, les répartitions optimales pour ces deux configurations du jeu :

# %%
dist = optimal_dist(chars, 150) # distribution optimale pour Big Boggle (150 lettres à répartir)
mse = mse_chardist(dist, chars)
show("dist; mse") # on doit obtenir 0.00023078049275844476 (ou pas loin)

# %%
dist = optimal_dist(chars, 216) # distribution optimale pour Super Boggle (216 lettres à répartir)
mse = mse_chardist(dist, chars)
show("dist; mse") # on doit obtenir 0.00010439336813255383 (ou pas loin)

# %% [markdown]
# Sans surprise, plus le nombre de lettres à répartir est grand, plus on peut se rapprocher de la distribution optimale, puisque les lettres rares seront plus proches de leur fréquence d'apparition réelle dans les mots de la langue française...

# %% [markdown]
# <h2 style="padding:0 0 8px; margin:0 -20px; color:#FFF; background:#07D; text-align:right">● ● ●</h3>
